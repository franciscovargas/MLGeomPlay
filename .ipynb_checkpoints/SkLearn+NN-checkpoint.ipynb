# %% [markdown]
# ## Logistic Regression
#
# Logistic regression is the base unit used in Neural networks. It is a clasifier that has a linear decision boundary. In other words it can only work well when data is linearly seperable as shown bellow:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
iris = datasets.load_iris()
model = LogisticRegression(max_iter= 1000)

# %%
iris_2class = iris["data"][:100,:2] # only take two dimensions to simplify

# %%
label = iris["target"][:100]

# %%
col = {1: "r", 0: "b"}
for i in range(len(iris_2class)):
    c = col[label[i]]
    x, y = iris_2class[i]
    plt.plot(x,y, "o" + c)

# %%
model.fit(iris_2class, label)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
sum(model.predict(iris_2class) == label)*100.0 / len(label) # One instance classified incorrectly
# Out:
# 99.0

# %%
m1, m2 = model.coef_[0]
c1 =model.intercept_[0]
m1,m2,c1
# Out:
# (2.2165737556011873, -3.6915233706589068, -0.59901123865342454)

# %%
# plotting decision boundaries:

x = np.arange(4,7,0.1)
y = -(m1/m2)*x -(c1/m2)#])
plt.plot(x,y)
for i in range(len(iris_2class)):
    c = col[label[i]]
    x, y = iris_2class[i]
    plt.plot(x,y, "o" + c)

# %% [markdown]
# ## Neural Networks
#
# Neural networks are used when data is not linearly seperable. Just like logistic regression neural nets fit striaght lines however the main difference is that they fit several lines (forming poligons) that allow us to classify correctly non linearly seperable data.
#
# The more Neurons (logistic regression units) the more lines we are fitting and the more complex shapes we can fit.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils.np_utils import to_categorical 

model = Sequential() # ins
model.add(Dense(output_dim=3, input_dim=2)) # Hidden layer with 3 lines (3 neurons)
model.add(Activation("relu"))
model.add(Dense(output_dim=1))
model.add(Activation("sigmoid"))

# compile model...
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-55fe829f829f> in <module>()
#       1
# ----> 2 from keras.models import Sequential
#       3 from keras.layers import Dense, Activation
#       4 from keras.utils.np_utils import to_categorical
#       5
#
# /usr/local/lib/python2.7/dist-packages/keras/__init__.py in <module>()
#       1 from __future__ import absolute_import
# ----> 2 from . import backend
#       3 from . import datasets
#       4 from . import engine
#       5 from . import layers
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/__init__.py in <module>()
#      65 elif _BACKEND == 'tensorflow':
#      66     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 67     from .tensorflow_backend import *
#      68 else:
#      69     raise ValueError('Unknown backend: ' + str(_BACKEND))
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.py in <module>()
# ----> 1 import tensorflow as tf
#       2
#       3 from tensorflow.python.training import moving_averages
#       4 from tensorflow.python.ops import tensor_array_ops
#       5 from tensorflow.python.ops import control_flow_ops
#
# ImportError: No module named tensorflow

# %%
# Generating non linear data

def sample_circle_points(r1=6, size=1000, ring=0):
    theta = np.random.uniform(- np.pi, np.pi, size)
    r = np.random.uniform(r1-ring, r1, size=size)
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return [x,y]

circle = sample_circle_points(r1=2, ring=2)
ring = sample_circle_points(ring=2)
labels = np.array( [0]*len(circle[0]) + [1]*len(ring[0]))
plt.plot(*(circle+["o"]) )
plt.plot(*(ring+["o"]) )

# %%
X= np.array([[x,y] for x,y in list(zip(*circle))] + [[i,j] for i,j in list(zip(*ring))])

# %%
model.fit(X, (labels), nb_epoch=120, batch_size=32)
# Out:
# Epoch 1/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 2/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 3/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 4/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 5/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 6/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 7/120
# 2000/2000 [==============================] - 0s - loss: 0.0029 - acc: 1.0000
# Epoch 8/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 9/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 10/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 11/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 12/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 13/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 14/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 15/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 16/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 17/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 18/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 19/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 20/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 21/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 22/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 23/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 24/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 25/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 26/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 27/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 28/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 29/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 30/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 31/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 32/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 33/120
# 2000/2000 [==============================] - 0s - loss: 0.0028 - acc: 1.0000
# Epoch 34/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 35/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 36/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 37/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 38/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 39/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 40/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 41/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 42/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 43/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 44/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 45/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 46/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 47/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 48/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 49/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 50/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 51/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 52/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 53/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 54/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 55/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 56/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 57/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 58/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 59/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 60/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 61/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 62/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 63/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 64/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 65/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 66/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 67/120
# 2000/2000 [==============================] - 0s - loss: 0.0027 - acc: 1.0000
# Epoch 68/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 69/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 70/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 71/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 72/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 73/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 74/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 75/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 76/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 77/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 78/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 79/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 80/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 81/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 82/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 83/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 84/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 85/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 86/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 87/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 88/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 89/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 90/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 91/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 92/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 93/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 94/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 95/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 96/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 97/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 98/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 99/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 100/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 101/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 102/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 103/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 104/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 105/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 106/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 107/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 108/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 109/120
# 2000/2000 [==============================] - 0s - loss: 0.0026 - acc: 1.0000
# Epoch 110/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 111/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 112/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 113/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 114/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 115/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 116/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 117/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 118/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 119/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000
# Epoch 120/120
# 2000/2000 [==============================] - 0s - loss: 0.0025 - acc: 1.0000

# %%
grads, intercepts = model.layers[2].get_weights() 
grads
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-66c38562c4ca> in <module>()
# ----> 1 grads, intercepts = model.layers[2].get_weights()
#       2 grads
#
# AttributeError: 'LogisticRegression' object has no attribute 'layers'

# %%
plt.plot(*(circle+["o"]) )
plt.plot(*(ring+["o"]) )

for i in range(len(grads.T)):
    print(i)
    m1 = grads[0][i]
    m2 = grads[1][i]
    c1 = intercepts[i]
    x = np.arange(-6,6,0.1)
    y = np.clip(-(m1/m2)*x -(c1/m2),-6,6)
    plt.plot(x,y)
# Out:
# 0
# 1
# 2
