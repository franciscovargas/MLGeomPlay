# %% [markdown]
# ## Logistic Regression
#
# Logistic regression is the base unit used in Neural networks. It is a clasifier that has a linear decision boundary. In other words it can only work well when data is linearly seperable as shown bellow:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import datasets
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
iris = datasets.load_iris()
model = LogisticRegression(max_iter= 1000)

# %%
iris_2class = iris["data"][:100,:2] # only take two dimensions to simplify

# %%
label = iris["target"][:100]

# %%
col = {1: "r", 0: "b"}
for i in range(len(iris_2class)):
    c = col[label[i]]
    x, y = iris_2class[i]
    plt.plot(x,y, "o" + c)

# %%
model.fit(iris_2class, label)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
sum(model.predict(iris_2class) == label)*100.0 / len(label) # One instance classified incorrectly
# Out:
# 99.0

# %%
m1, m2 = model.coef_[0]
c1 =model.intercept_[0]
m1,m2,c1
# Out:
# (2.2165737556011873, -3.6915233706589068, -0.59901123865342454)

# %%
# plotting decision boundaries:

x = np.arange(4,7,0.1)
y = -(m1/m2)*x -(c1/m2)#])
plt.plot(x,y)
for i in range(len(iris_2class)):
    c = col[label[i]]
    x, y = iris_2class[i]
    plt.plot(x,y, "o" + c)

# %% [markdown]
# ## Neural Networks
#
# Neural networks are used when data is not linearly seperable. Just like logistic regression neural nets fit striaght lines however the main difference is that they fit several lines (forming poligons) that allow us to classify correctly non linearly seperable data.
#
# The more Neurons (logistic regression units) the more lines we are fitting and the more complex shapes we can fit.

# %%
# compiling a keras network with topology 
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils.np_utils import to_categorical 

model = Sequential() # ins
model.add(Dense(output_dim=3, input_dim=2)) # Hidden layer with 3 lines (3 neurons)
model.add(Activation("sigmoid"))
model.add(Dense(output_dim=1))
model.add(Activation("sigmoid"))

# compile model...
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
# Generating non linear data

def sample_circle_points(r1=6, size=1000, ring=0):
    theta = np.random.uniform(- np.pi, np.pi, size)
    r = np.random.uniform(r1-ring, r1, size=size)
    x = r * np.cos(theta)
    y = r * np.sin(theta)
    return [x,y]

circle = sample_circle_points(r1=2, ring=2)
ring = sample_circle_points(ring=2)
labels = np.array( [0]*len(circle[0]) + [1]*len(ring[0]))
plt.plot(*(circle+["o"]) )
plt.plot(*(ring+["o"]) )

# %%
X= np.array([[x,y] for x,y in list(zip(*circle))] + [[i,j] for i,j in list(zip(*ring))])

# %%
# training net to 100* accuracy
model.fit(X, (labels), nb_epoch=200, batch_size=32)
# Out:
# Epoch 1/200
# 2000/2000 [==============================] - 0s - loss: 0.2061 - acc: 0.9470
# Epoch 2/200
# 2000/2000 [==============================] - 0s - loss: 0.2054 - acc: 0.9475
# Epoch 3/200
# 2000/2000 [==============================] - 0s - loss: 0.2047 - acc: 0.9475
# Epoch 4/200
# 2000/2000 [==============================] - 0s - loss: 0.2040 - acc: 0.9475
# Epoch 5/200
# 2000/2000 [==============================] - 0s - loss: 0.2033 - acc: 0.9475
# Epoch 6/200
# 2000/2000 [==============================] - 0s - loss: 0.2026 - acc: 0.9475
# Epoch 7/200
# 2000/2000 [==============================] - 0s - loss: 0.2018 - acc: 0.9485
# Epoch 8/200
# 2000/2000 [==============================] - 0s - loss: 0.2011 - acc: 0.9485
# Epoch 9/200
# 2000/2000 [==============================] - 0s - loss: 0.2004 - acc: 0.9490
# Epoch 10/200
# 2000/2000 [==============================] - 0s - loss: 0.1997 - acc: 0.9490
# Epoch 11/200
# 2000/2000 [==============================] - 0s - loss: 0.1990 - acc: 0.9495
# Epoch 12/200
# 2000/2000 [==============================] - 0s - loss: 0.1983 - acc: 0.9495
# Epoch 13/200
# 2000/2000 [==============================] - 0s - loss: 0.1976 - acc: 0.9495
# Epoch 14/200
# 2000/2000 [==============================] - 0s - loss: 0.1970 - acc: 0.9495
# Epoch 15/200
# 2000/2000 [==============================] - 0s - loss: 0.1963 - acc: 0.9500
# Epoch 16/200
# 2000/2000 [==============================] - 0s - loss: 0.1956 - acc: 0.9500
# Epoch 17/200
# 2000/2000 [==============================] - 0s - loss: 0.1949 - acc: 0.9505
# Epoch 18/200
# 2000/2000 [==============================] - 0s - loss: 0.1942 - acc: 0.9510
# Epoch 19/200
# 2000/2000 [==============================] - 0s - loss: 0.1936 - acc: 0.9505
# Epoch 20/200
# 2000/2000 [==============================] - 0s - loss: 0.1929 - acc: 0.9515
# Epoch 21/200
# 2000/2000 [==============================] - 0s - loss: 0.1922 - acc: 0.9515
# Epoch 22/200
# 2000/2000 [==============================] - 0s - loss: 0.1916 - acc: 0.9515
# Epoch 23/200
# 2000/2000 [==============================] - 0s - loss: 0.1909 - acc: 0.9515
# Epoch 24/200
# 2000/2000 [==============================] - 0s - loss: 0.1903 - acc: 0.9515
# Epoch 25/200
# 2000/2000 [==============================] - 0s - loss: 0.1896 - acc: 0.9515
# Epoch 26/200
# 2000/2000 [==============================] - 0s - loss: 0.1890 - acc: 0.9515
# Epoch 27/200
# 2000/2000 [==============================] - 0s - loss: 0.1883 - acc: 0.9520
# Epoch 28/200
# 2000/2000 [==============================] - 0s - loss: 0.1877 - acc: 0.9520
# Epoch 29/200
# 2000/2000 [==============================] - 0s - loss: 0.1870 - acc: 0.9520
# Epoch 30/200
# 2000/2000 [==============================] - 0s - loss: 0.1864 - acc: 0.9525
# Epoch 31/200
# 2000/2000 [==============================] - 0s - loss: 0.1857 - acc: 0.9525
# Epoch 32/200
# 2000/2000 [==============================] - 0s - loss: 0.1851 - acc: 0.9535
# Epoch 33/200
# 2000/2000 [==============================] - 0s - loss: 0.1845 - acc: 0.9535
# Epoch 34/200
# 2000/2000 [==============================] - 0s - loss: 0.1839 - acc: 0.9545
# Epoch 35/200
# 2000/2000 [==============================] - 0s - loss: 0.1832 - acc: 0.9555
# Epoch 36/200
# 2000/2000 [==============================] - 0s - loss: 0.1826 - acc: 0.9565
# Epoch 37/200
# 2000/2000 [==============================] - 0s - loss: 0.1820 - acc: 0.9570
# Epoch 38/200
# 2000/2000 [==============================] - 0s - loss: 0.1814 - acc: 0.9595
# Epoch 39/200
# 2000/2000 [==============================] - 0s - loss: 0.1808 - acc: 0.9605
# Epoch 40/200
# 2000/2000 [==============================] - 0s - loss: 0.1802 - acc: 0.9630
# Epoch 41/200
# 2000/2000 [==============================] - 0s - loss: 0.1796 - acc: 0.9640
# Epoch 42/200
# 2000/2000 [==============================] - 0s - loss: 0.1790 - acc: 0.9665
# Epoch 43/200
# 2000/2000 [==============================] - 0s - loss: 0.1784 - acc: 0.9700
# Epoch 44/200
# 2000/2000 [==============================] - 0s - loss: 0.1778 - acc: 0.9740
# Epoch 45/200
# 2000/2000 [==============================] - 0s - loss: 0.1772 - acc: 0.9795
# Epoch 46/200
# 2000/2000 [==============================] - 0s - loss: 0.1766 - acc: 0.9825
# Epoch 47/200
# 2000/2000 [==============================] - 0s - loss: 0.1760 - acc: 0.9840
# Epoch 48/200
# 2000/2000 [==============================] - 0s - loss: 0.1754 - acc: 0.9880
# Epoch 49/200
# 2000/2000 [==============================] - 0s - loss: 0.1748 - acc: 0.9885
# Epoch 50/200
# 2000/2000 [==============================] - 0s - loss: 0.1743 - acc: 0.9920
# Epoch 51/200
# 2000/2000 [==============================] - 0s - loss: 0.1737 - acc: 0.9935
# Epoch 52/200
# 2000/2000 [==============================] - 0s - loss: 0.1731 - acc: 0.9950
# Epoch 53/200
# 2000/2000 [==============================] - 0s - loss: 0.1725 - acc: 0.9965
# Epoch 54/200
# 2000/2000 [==============================] - 0s - loss: 0.1720 - acc: 0.9970
# Epoch 55/200
# 2000/2000 [==============================] - 0s - loss: 0.1714 - acc: 0.9970
# Epoch 56/200
# 2000/2000 [==============================] - 0s - loss: 0.1708 - acc: 0.9980
# Epoch 57/200
# 2000/2000 [==============================] - 0s - loss: 0.1703 - acc: 0.9990
# Epoch 58/200
# 2000/2000 [==============================] - 0s - loss: 0.1697 - acc: 0.9995
# Epoch 59/200
# 2000/2000 [==============================] - 0s - loss: 0.1692 - acc: 0.9995
# Epoch 60/200
# 2000/2000 [==============================] - 0s - loss: 0.1686 - acc: 0.9995
# Epoch 61/200
# 2000/2000 [==============================] - 0s - loss: 0.1681 - acc: 0.9995
# Epoch 62/200
# 2000/2000 [==============================] - 0s - loss: 0.1675 - acc: 0.9995
# Epoch 63/200
# 2000/2000 [==============================] - 0s - loss: 0.1670 - acc: 0.9995
# Epoch 64/200
# 2000/2000 [==============================] - 0s - loss: 0.1665 - acc: 0.9995
# Epoch 65/200
# 2000/2000 [==============================] - 0s - loss: 0.1659 - acc: 0.9995
# Epoch 66/200
# 2000/2000 [==============================] - 0s - loss: 0.1654 - acc: 0.9995
# Epoch 67/200
# 2000/2000 [==============================] - 0s - loss: 0.1648 - acc: 0.9995
# Epoch 68/200
# 2000/2000 [==============================] - 0s - loss: 0.1643 - acc: 0.9995
# Epoch 69/200
# 2000/2000 [==============================] - 0s - loss: 0.1638 - acc: 0.9995
# Epoch 70/200
# 2000/2000 [==============================] - 0s - loss: 0.1633 - acc: 0.9995
# Epoch 71/200
# 2000/2000 [==============================] - 0s - loss: 0.1628 - acc: 0.9995
# Epoch 72/200
# 2000/2000 [==============================] - 0s - loss: 0.1622 - acc: 0.9995
# Epoch 73/200
# 2000/2000 [==============================] - 0s - loss: 0.1617 - acc: 0.9995
# Epoch 74/200
# 2000/2000 [==============================] - 0s - loss: 0.1612 - acc: 0.9995
# Epoch 75/200
# 2000/2000 [==============================] - 0s - loss: 0.1607 - acc: 0.9995
# Epoch 76/200
# 2000/2000 [==============================] - 0s - loss: 0.1602 - acc: 0.9995
# Epoch 77/200
# 2000/2000 [==============================] - 0s - loss: 0.1597 - acc: 1.0000
# Epoch 78/200
# 2000/2000 [==============================] - 0s - loss: 0.1592 - acc: 1.0000
# Epoch 79/200
# 2000/2000 [==============================] - 0s - loss: 0.1587 - acc: 1.0000
# Epoch 80/200
# 2000/2000 [==============================] - 0s - loss: 0.1582 - acc: 1.0000
# Epoch 81/200
# 2000/2000 [==============================] - 0s - loss: 0.1577 - acc: 1.0000
# Epoch 82/200
# 2000/2000 [==============================] - 0s - loss: 0.1572 - acc: 1.0000
# Epoch 83/200
# 2000/2000 [==============================] - 0s - loss: 0.1567 - acc: 1.0000
# Epoch 84/200
# 2000/2000 [==============================] - 0s - loss: 0.1562 - acc: 1.0000
# Epoch 85/200
# 2000/2000 [==============================] - 0s - loss: 0.1557 - acc: 1.0000
# Epoch 86/200
# 2000/2000 [==============================] - 0s - loss: 0.1552 - acc: 1.0000
# Epoch 87/200
# 2000/2000 [==============================] - 0s - loss: 0.1548 - acc: 1.0000
# Epoch 88/200
# 2000/2000 [==============================] - 0s - loss: 0.1543 - acc: 1.0000
# Epoch 89/200
# 2000/2000 [==============================] - 0s - loss: 0.1538 - acc: 1.0000
# Epoch 90/200
# 2000/2000 [==============================] - 0s - loss: 0.1533 - acc: 1.0000
# Epoch 91/200
# 2000/2000 [==============================] - 0s - loss: 0.1529 - acc: 1.0000
# Epoch 92/200
# 2000/2000 [==============================] - 0s - loss: 0.1524 - acc: 1.0000
# Epoch 93/200
# 2000/2000 [==============================] - 0s - loss: 0.1519 - acc: 1.0000
# Epoch 94/200
# 2000/2000 [==============================] - 0s - loss: 0.1515 - acc: 1.0000
# Epoch 95/200
# 2000/2000 [==============================] - 0s - loss: 0.1510 - acc: 1.0000
# Epoch 96/200
# 2000/2000 [==============================] - 0s - loss: 0.1505 - acc: 1.0000
# Epoch 97/200
# 2000/2000 [==============================] - 0s - loss: 0.1501 - acc: 1.0000
# Epoch 98/200
# 2000/2000 [==============================] - 0s - loss: 0.1496 - acc: 1.0000
# Epoch 99/200
# 2000/2000 [==============================] - 0s - loss: 0.1492 - acc: 1.0000
# Epoch 100/200
# 2000/2000 [==============================] - 0s - loss: 0.1487 - acc: 1.0000
# Epoch 101/200
# 2000/2000 [==============================] - 0s - loss: 0.1483 - acc: 1.0000
# Epoch 102/200
# 2000/2000 [==============================] - 0s - loss: 0.1478 - acc: 1.0000
# Epoch 103/200
# 2000/2000 [==============================] - 0s - loss: 0.1474 - acc: 1.0000
# Epoch 104/200
# 2000/2000 [==============================] - 0s - loss: 0.1469 - acc: 1.0000
# Epoch 105/200
# 2000/2000 [==============================] - 0s - loss: 0.1465 - acc: 1.0000
# Epoch 106/200
# 2000/2000 [==============================] - 0s - loss: 0.1461 - acc: 1.0000
# Epoch 107/200
# 2000/2000 [==============================] - 0s - loss: 0.1456 - acc: 1.0000
# Epoch 108/200
# 2000/2000 [==============================] - 0s - loss: 0.1452 - acc: 1.0000
# Epoch 109/200
# 2000/2000 [==============================] - 0s - loss: 0.1448 - acc: 1.0000
# Epoch 110/200
# 2000/2000 [==============================] - 0s - loss: 0.1443 - acc: 1.0000
# Epoch 111/200
# 2000/2000 [==============================] - 0s - loss: 0.1439 - acc: 1.0000
# Epoch 112/200
# 2000/2000 [==============================] - 0s - loss: 0.1435 - acc: 1.0000
# Epoch 113/200
# 2000/2000 [==============================] - 0s - loss: 0.1430 - acc: 1.0000
# Epoch 114/200
# 2000/2000 [==============================] - 0s - loss: 0.1426 - acc: 1.0000
# Epoch 115/200
# 2000/2000 [==============================] - 0s - loss: 0.1422 - acc: 1.0000
# Epoch 116/200
# 2000/2000 [==============================] - 0s - loss: 0.1418 - acc: 1.0000
# Epoch 117/200
# 2000/2000 [==============================] - 0s - loss: 0.1414 - acc: 1.0000
# Epoch 118/200
# 2000/2000 [==============================] - 0s - loss: 0.1410 - acc: 1.0000
# Epoch 119/200
# 2000/2000 [==============================] - 0s - loss: 0.1405 - acc: 1.0000
# Epoch 120/200
# 2000/2000 [==============================] - 0s - loss: 0.1401 - acc: 1.0000
# Epoch 121/200
# 2000/2000 [==============================] - 0s - loss: 0.1397 - acc: 1.0000
# Epoch 122/200
# 2000/2000 [==============================] - 0s - loss: 0.1393 - acc: 1.0000
# Epoch 123/200
# 2000/2000 [==============================] - 0s - loss: 0.1389 - acc: 1.0000
# Epoch 124/200
# 2000/2000 [==============================] - 0s - loss: 0.1385 - acc: 1.0000
# Epoch 125/200
# 2000/2000 [==============================] - 0s - loss: 0.1381 - acc: 1.0000
# Epoch 126/200
# 2000/2000 [==============================] - 0s - loss: 0.1377 - acc: 1.0000
# Epoch 127/200
# 2000/2000 [==============================] - 0s - loss: 0.1373 - acc: 1.0000
# Epoch 128/200
# 2000/2000 [==============================] - 0s - loss: 0.1369 - acc: 1.0000
# Epoch 129/200
# 2000/2000 [==============================] - 0s - loss: 0.1365 - acc: 1.0000
# Epoch 130/200
# 2000/2000 [==============================] - 0s - loss: 0.1361 - acc: 1.0000
# Epoch 131/200
# 2000/2000 [==============================] - 0s - loss: 0.1358 - acc: 1.0000
# Epoch 132/200
# 2000/2000 [==============================] - 0s - loss: 0.1354 - acc: 1.0000
# Epoch 133/200
# 2000/2000 [==============================] - 0s - loss: 0.1350 - acc: 1.0000
# Epoch 134/200
# 2000/2000 [==============================] - 0s - loss: 0.1346 - acc: 1.0000
# Epoch 135/200
# 2000/2000 [==============================] - 0s - loss: 0.1342 - acc: 1.0000
# Epoch 136/200
# 2000/2000 [==============================] - 0s - loss: 0.1339 - acc: 1.0000
# Epoch 137/200
# 2000/2000 [==============================] - 0s - loss: 0.1335 - acc: 1.0000
# Epoch 138/200
# 2000/2000 [==============================] - 0s - loss: 0.1331 - acc: 1.0000
# Epoch 139/200
# 2000/2000 [==============================] - 0s - loss: 0.1327 - acc: 1.0000
# Epoch 140/200
# 2000/2000 [==============================] - 0s - loss: 0.1324 - acc: 1.0000
# Epoch 141/200
# 2000/2000 [==============================] - 0s - loss: 0.1320 - acc: 1.0000
# Epoch 142/200
# 2000/2000 [==============================] - 0s - loss: 0.1316 - acc: 1.0000
# Epoch 143/200
# 2000/2000 [==============================] - 0s - loss: 0.1312 - acc: 1.0000
# Epoch 144/200
# 2000/2000 [==============================] - 0s - loss: 0.1309 - acc: 1.0000
# Epoch 145/200
# 2000/2000 [==============================] - 0s - loss: 0.1305 - acc: 1.0000
# Epoch 146/200
# 2000/2000 [==============================] - 0s - loss: 0.1302 - acc: 1.0000
# Epoch 147/200
# 2000/2000 [==============================] - 0s - loss: 0.1298 - acc: 1.0000
# Epoch 148/200
# 2000/2000 [==============================] - 0s - loss: 0.1294 - acc: 1.0000
# Epoch 149/200
# 2000/2000 [==============================] - 0s - loss: 0.1291 - acc: 1.0000
# Epoch 150/200
# 2000/2000 [==============================] - 0s - loss: 0.1287 - acc: 1.0000
# Epoch 151/200
# 2000/2000 [==============================] - 0s - loss: 0.1284 - acc: 1.0000
# Epoch 152/200
# 2000/2000 [==============================] - 0s - loss: 0.1280 - acc: 1.0000
# Epoch 153/200
# 2000/2000 [==============================] - 0s - loss: 0.1277 - acc: 1.0000
# Epoch 154/200
# 2000/2000 [==============================] - 0s - loss: 0.1273 - acc: 1.0000
# Epoch 155/200
# 2000/2000 [==============================] - 0s - loss: 0.1270 - acc: 1.0000
# Epoch 156/200
# 2000/2000 [==============================] - 0s - loss: 0.1266 - acc: 1.0000
# Epoch 157/200
# 2000/2000 [==============================] - 0s - loss: 0.1263 - acc: 1.0000
# Epoch 158/200
# 2000/2000 [==============================] - 0s - loss: 0.1259 - acc: 1.0000
# Epoch 159/200
# 2000/2000 [==============================] - 0s - loss: 0.1256 - acc: 1.0000
# Epoch 160/200
# 2000/2000 [==============================] - 0s - loss: 0.1253 - acc: 1.0000
# Epoch 161/200
# 2000/2000 [==============================] - 0s - loss: 0.1249 - acc: 1.0000
# Epoch 162/200
# 2000/2000 [==============================] - 0s - loss: 0.1246 - acc: 1.0000
# Epoch 163/200
# 2000/2000 [==============================] - 0s - loss: 0.1243 - acc: 1.0000
# Epoch 164/200
# 2000/2000 [==============================] - 0s - loss: 0.1239 - acc: 1.0000
# Epoch 165/200
# 2000/2000 [==============================] - 0s - loss: 0.1236 - acc: 1.0000
# Epoch 166/200
# 2000/2000 [==============================] - 0s - loss: 0.1233 - acc: 1.0000
# Epoch 167/200
# 2000/2000 [==============================] - 0s - loss: 0.1229 - acc: 1.0000
# Epoch 168/200
# 2000/2000 [==============================] - 0s - loss: 0.1226 - acc: 1.0000
# Epoch 169/200
# 2000/2000 [==============================] - 0s - loss: 0.1223 - acc: 1.0000
# Epoch 170/200
# 2000/2000 [==============================] - 0s - loss: 0.1220 - acc: 1.0000
# Epoch 171/200
# 2000/2000 [==============================] - 0s - loss: 0.1217 - acc: 1.0000
# Epoch 172/200
# 2000/2000 [==============================] - 0s - loss: 0.1213 - acc: 1.0000
# Epoch 173/200
# 2000/2000 [==============================] - 0s - loss: 0.1210 - acc: 1.0000
# Epoch 174/200
# 2000/2000 [==============================] - 0s - loss: 0.1207 - acc: 1.0000
# Epoch 175/200
# 2000/2000 [==============================] - 0s - loss: 0.1204 - acc: 1.0000
# Epoch 176/200
# 2000/2000 [==============================] - 0s - loss: 0.1201 - acc: 1.0000
# Epoch 177/200
# 2000/2000 [==============================] - 0s - loss: 0.1198 - acc: 1.0000
# Epoch 178/200
# 2000/2000 [==============================] - 0s - loss: 0.1194 - acc: 1.0000
# Epoch 179/200
# 2000/2000 [==============================] - 0s - loss: 0.1191 - acc: 1.0000
# Epoch 180/200
# 2000/2000 [==============================] - 0s - loss: 0.1188 - acc: 1.0000
# Epoch 181/200
# 2000/2000 [==============================] - 0s - loss: 0.1185 - acc: 1.0000
# Epoch 182/200
# 2000/2000 [==============================] - 0s - loss: 0.1182 - acc: 1.0000
# Epoch 183/200
# 2000/2000 [==============================] - 0s - loss: 0.1179 - acc: 1.0000
# Epoch 184/200
# 2000/2000 [==============================] - 0s - loss: 0.1176 - acc: 1.0000
# Epoch 185/200
# 2000/2000 [==============================] - 0s - loss: 0.1173 - acc: 1.0000
# Epoch 186/200
# 2000/2000 [==============================] - 0s - loss: 0.1170 - acc: 1.0000
# Epoch 187/200
# 2000/2000 [==============================] - 0s - loss: 0.1167 - acc: 1.0000
# Epoch 188/200
# 2000/2000 [==============================] - 0s - loss: 0.1164 - acc: 1.0000
# Epoch 189/200
# 2000/2000 [==============================] - 0s - loss: 0.1161 - acc: 1.0000
# Epoch 190/200
# 2000/2000 [==============================] - 0s - loss: 0.1158 - acc: 1.0000
# Epoch 191/200
# 2000/2000 [==============================] - 0s - loss: 0.1155 - acc: 1.0000
# Epoch 192/200
# 2000/2000 [==============================] - 0s - loss: 0.1152 - acc: 1.0000
# Epoch 193/200
# 2000/2000 [==============================] - 0s - loss: 0.1149 - acc: 1.0000
# Epoch 194/200
# 2000/2000 [==============================] - 0s - loss: 0.1147 - acc: 1.0000
# Epoch 195/200
# 2000/2000 [==============================] - 0s - loss: 0.1144 - acc: 1.0000
# Epoch 196/200
# 2000/2000 [==============================] - 0s - loss: 0.1141 - acc: 1.0000
# Epoch 197/200
#  - 0s - loss: 0.1138 - acc: 1.0000
# Epoch 198/200
# 2000/2000 [==============================] - 0s - loss: 0.1135 - acc: 1.0000
# Epoch 199/200
# 2000/2000 [==============================] - 0s - loss: 0.1132 - acc: 1.0000
# Epoch 200/200
# 2000/2000 [==============================] - 0s - loss: 0.1129 - acc: 1.0000

# %%
grads, intercepts = model.layers[0].get_weights() 
grads
# Out:
# array([[-0.02533619,  1.56212711, -1.51818466],
#        [ 1.98637438,  1.41373563,  0.89575428]], dtype=float32)

# %%
plt.plot(*(circle+["o"]) )
plt.plot(*(ring+["o"]) )
# Plotting hyperplanes of layer 1
for i in range(len(grads.T)):
    print(i)
    m1 = grads[0][i]
    m2 = grads[1][i]
    c1 = intercepts[i]
    x = np.arange(-6,6,0.1)
    y = np.clip(-(m1/m2)*x -(c1/m2),-6,6)
    plt.plot(x,y)
# Out:
# 0
# 1
# 2

# %%
# meshgrid for all points on plain ... there is probably a nice numpy way of doing this
from itertools import chain
xx ,yy = np.meshgrid(np.arange(-6,6,0.1) , np.arange(-6,6,0.1))
X2 = np.array(list(chain(*[zip(i,j) for i,j in zip(xx, yy)])))

# %%
label = model.predict_classes(X2)
label2 = model.predict_classes(X)
# Out:
# 1312/2000 [==================>...........] - ETA: 0s0s

# %%
# plotting classification over meshgrid to portray 
# real picture of decision boundaries 

for i in range(len(X2)):
    c = col[label[i][0]]
    x, y = X2[i]
    plt.plot(x,y, "o" + c)
    

col2 = {1: "salmon", 0: "cyan"}
for i in range(len(X)):
    c = col2[label2[i][0]]
    x, y = X[i]
    plt.plot(x,y, "o" , color= c, alpha=0.5)

# %%
label = model.predict(X2)

# %%
plt.pcolormesh(xx,yy, label.reshape(120,120))

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.gca(projection='3d')

# Plot the surface.
surf = ax.plot_surface(xx,yy, -1*label.reshape(120,120), cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)
